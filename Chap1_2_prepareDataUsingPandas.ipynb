# %% [markdown]
# <a href="https://colab.research.google.com/github/zfukuoka/Training-KikaiGakusyuZukan/blob/master/Chap1_2_prepareDataUsingPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.2 機械学習に必要なステップ
#
# ## pandasを使ったデータの理解と加工
#
# * 機械学習を行う上で、特徴量を確認したり、データの取捨選択をしたり、データの再加工を行うことがある
# * ここではpandasを用いたデータの可視化機能に触れる

# %%
import pandas as pd

# %% [markdown]
# * 下記は一旦読み込んだデータをpandasに代入して、head()を用いて先頭の5レコードを表示

# %%
from sklearn.datasets import load_wine
data = load_wine()
df_X = pd.DataFrame(data.data, columns=data.feature_names)
df_X.head()
# Out:
#    alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %% [markdown]
# * 同じく、結果である data.target を pandas に代入して、先頭5レコードを表示

# %%
df_y = pd.DataFrame(data.target, columns=["kind(target)"])
df_y.head()
# Out:
#    kind(target)
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# * concat() で 変数df_X と 変数df_y を連結

# %%
df = pd.concat([df_X, df_y], axis=1)
df.head()
# Out:
#    alcohol  malic_acid  ...  proline  kind(target)
# 0    14.23        1.71  ...   1065.0             0
# 1    13.20        1.78  ...   1050.0             0
# 2    13.16        2.36  ...   1185.0             0
# 3    14.37        1.95  ...   1480.0             0
# 4    13.24        2.59  ...    735.0             0
#
# [5 rows x 14 columns]

# %% [markdown]
# * alcohol列をヒストグラムで表示
#   * 下記の例では hist() に binsパラメータを設定していないため、デフォルトの10が適用

# %%
import matplotlib.pyplot as plt
plt.hist(df.loc[:, "alcohol"])
# Out:
# (array([ 1., 10., 19., 31., 21., 27., 25., 25., 17.,  2.]),
#  array([11.03, 11.41, 11.79, 12.17, 12.55, 12.93, 13.31, 13.69, 14.07,
#         14.45, 14.83]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# * alcohol列のデータを箱ひげ図で表示

# %%
plt.boxplot(df.loc[:, "alcohol"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3221f8ada0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3221f9a748>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3221f26160>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3221f9add8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3221f9a0f0>,
#   <matplotlib.lines.Line2D at 0x7f3221f9a400>]}

# %% [markdown]
# * corr() を用いて相関関係をまとめて計算して出力
#   * 1に近づくほど、正の相関関係
#   * -1に近づくほど、負の相関関係
#   * 0周辺はデータ同士の相関が低い

# %%
df.corr()
# Out:
#                                alcohol  malic_acid  ...   proline  kind(target)
# alcohol                       1.000000    0.094397  ...  0.643720     -0.328222
# malic_acid                    0.094397    1.000000  ... -0.192011      0.437776
# ash                           0.211545    0.164045  ...  0.223626     -0.049643
# alcalinity_of_ash            -0.310235    0.288500  ... -0.440597      0.517859
# magnesium                     0.270798   -0.054575  ...  0.393351     -0.209179
# total_phenols                 0.289101   -0.335167  ...  0.498115     -0.719163
# flavanoids                    0.236815   -0.411007  ...  0.494193     -0.847498
# nonflavanoid_phenols         -0.155929    0.292977  ... -0.311385      0.489109
# proanthocyanins               0.136698   -0.220746  ...  0.330417     -0.499130
# color_intensity               0.546364    0.248985  ...  0.316100      0.265668
# hue                          -0.071747   -0.561296  ...  0.236183     -0.617369
# ...

# %% [markdown]
# * describe() で列ごとに統計情報を出力
#   * 出力される統計情報は、上から順に件数・平均値・標準偏差・最低値・25パーセンタイル・中央値・75パーセンタイル・最大値
#   * この情報からどのようなデータの特性やデータ欠損を見れる

# %%
df.describe()
# Out:
#           alcohol  malic_acid  ...      proline  kind(target)
# count  178.000000  178.000000  ...   178.000000    178.000000
# mean    13.000618    2.336348  ...   746.893258      0.938202
# std      0.811827    1.117146  ...   314.907474      0.775035
# min     11.030000    0.740000  ...   278.000000      0.000000
# 25%     12.362500    1.602500  ...   500.500000      0.000000
# 50%     13.050000    1.865000  ...   673.500000      1.000000
# 75%     13.677500    3.082500  ...   985.000000      2.000000
# max     14.830000    5.800000  ...  1680.000000      2.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# * scatter_matrixを用いて、散布図行列を出力

# %%
from pandas.plotting import scatter_matrix
_ = scatter_matrix(df, figsize=(15,15))

# %% [markdown]
# * 一部の関連性だけを調べたいときは、引数の指定で範囲を指定

# %%
_ = scatter_matrix(df.iloc[:, [0, 9, -1]])
